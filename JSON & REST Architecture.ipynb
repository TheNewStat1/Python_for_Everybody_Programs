# %% [markdown]
# # What is JSON?

# %% [markdown]
# JSON is also a data Serialization/De-serialization format for data just like XML.

# %% [markdown]
# One advantage however that JSON has over XML is that it is simpiler in situations where complexity of the program
# is low

# %% [markdown]
# The notation is based on the literal object notation from the Javascript programming language

# %% [markdown]
# In JSON data is basically represented in Nested lists (or dictionaries) vs. say a mark-up like XML

# %%
## Here is an example at work of Reading in the JSON file
import json # We have to import the json package

# Here is the example JSON data format 
# its like a dictionary notice the {} brackets
data = '''
{
  "name" : "Chuck",
  "phone" : {
    "type" : "intl",
    "number" : "+1 734 303 4456"
   },
   "email" : {
     "hide" : "yes"
   }
}'''

info = json.loads(data) # using the loads() function in json lib to read in the data into variable info
    # The nice part, what we get back when we read in this data is that info is a python 'dictionary'
# Note. the python dictonary syntax is used to print the data below
print('Name:', info["name"]) 
print('Hide:', info["email"]["hide"]) # here a dictonary key 'email' is further referenced with key 'hide'
    # remember since info["email"] is a dictionary we reference that with a key item
# Out:
# Name: Chuck
# Hide: yes

# %%
# This next example shows how extract JSON data when that is a list
import json

# Now this data is like a list in JSON
# its like a list notice the [] brackets
data = '''
[
  { "id" : "001",
    "x" : "2",
    "name" : "Chuck"
  } ,
  { "id" : "009",
    "x" : "7",
    "name" : "Brent"
  }
]'''

info = json.loads(data)
print(type(info))
print('User count:', len(info))

# Basically now that we have a list in python we can for-loop right through it
for item in info:
    print('Name', item['name'])
    print('Id', item['id'])
    print('Attribute', item['x'])
# Out:
# <class 'list'>
# User count: 2
# Name Chuck
# Id 001
# Attribute 2
# Name Brent
# Id 009
# Attribute 7

# %% [markdown]
# # Idea of Service Oriented Approach

# %% [markdown]
# Most applications use a form of web-service

# %% [markdown]
# An API are essentially the published "rules" applications must follow to make use of the "services"

# %% [markdown]
# Here is an example of code that does an API request to Googles geocoded API. Below is the API syntax for the requested data

# %% [markdown]
# https://maps.googleapis.com/maps/api/geocode/json?address=Ann+Arbor%2C+MI&key=AIzaSyBxRzMh7hZA5MEh2VYtbC_O6D3hUw6ibUY
# * The &key part is the API key provided by google cloud
# * after json? we write the components of the request that we want
# * '+' means spaces
# * % means commas

# %% [markdown]
# Below is the data from the API request above

# %% [raw]
# {
#   "results": [
#     {
#       "address_components": [
#         {
#           "long_name": "Ann Arbor",
#           "short_name": "Ann Arbor",
#           "types": [
#             "locality",
#             "political"
#           ]
#         },
#         {
#           "long_name": "Washtenaw County",
#           "short_name": "Washtenaw County",
#           "types": [
#             "administrative_area_level_2",
#             "political"
#           ]
#         },
#         {
#           "long_name": "Michigan",
#           "short_name": "MI",
#           "types": [
#             "administrative_area_level_1",
#             "political"
#           ]
#         },
#         {
#           "long_name": "United States",
#           "short_name": "US",
#           "types": [
#             "country",
#             "political"
#           ]
#         }
#       ],
#       "formatted_address": "Ann Arbor, MI, USA",
#       "geometry": {
#         "bounds": {
#           "northeast": {
#             "lat": 42.3239728,
#             "lng": -83.6758069
#           },
#           "southwest": {
#             "lat": 42.222668,
#             "lng": -83.799572
#           }
#         },
#         "location": {
#           "lat": 42.2808256,
#           "lng": -83.7430378
#         },
#         "location_type": "APPROXIMATE",
#         "viewport": {
#           "northeast": {
#             "lat": 42.3239728,
#             "lng": -83.6758069
#           },
#           "southwest": {
#             "lat": 42.222668,
#             "lng": -83.799572
#           }
#         }
#       },
#       "place_id": "ChIJMx9D1A2wPIgR4rXIhkb5Cds",
#       "types": [
#         "locality",
#         "political"
#       ]
#     }
#   ],
#   "status": "OK"
# }

# %%
# This code below is used to get the request
import urllib.request, urllib.parse, urllib.error
import json
import ssl

api_key = 'AIzaSyBxRzMh7hZA5MEh2VYtbC_O6D3hUw6ibUY' # Note. here I put my Google Maps API key
# If you have a Google Places API key, enter it here
# api_key = 'AIzaSy___IDByT70'
# https://developers.google.com/maps/documentation/geocoding/intro

if api_key is False:
    api_key = 42
    serviceurl = 'http://py4e-data.dr-chuck.net/json?'
else :
    serviceurl = 'https://maps.googleapis.com/maps/api/geocode/json?'

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

while True:
    address = input('Enter location: ')
    if len(address) < 1: break

    parms = dict()
    parms['address'] = address
    if api_key is not False: parms['key'] = api_key
    url = serviceurl + urllib.parse.urlencode(parms) # concatenates the serviceurl with the (input + api key)

    print('Retrieving', url)
    uh = urllib.request.urlopen(url, context=ctx)
    data = uh.read().decode()
    print('Retrieved', len(data), 'characters')

    try:
        js = json.loads(data)
    except:
        js = None

    if not js or 'status' not in js or js['status'] != 'OK':
        print('==== Failure To Retrieve ====')
        print(data)
        continue

    print(json.dumps(js, indent=4))

    lat = js['results'][0]['geometry']['location']['lat']
    lng = js['results'][0]['geometry']['location']['lng']
    print('lat', lat, 'lng', lng)
    location = js['results'][0]['formatted_address']
    print(location)
# Out:
# Enter location: Brandon, FL
# Retrieving https://maps.googleapis.com/maps/api/geocode/json?address=Brandon%2C+FL&key=AIzaSyBxRzMh7hZA5MEh2VYtbC_O6D3hUw6ibUY
# Retrieved 1734 characters
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Brandon",
#                     "short_name": "Brandon",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Hillsborough County",
#                     "short_name": "Hillsborough County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Florida",
#                     "short_name": "FL",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Brandon, FL, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 27.9780931,
#                         "lng": -82.2438568
#                     },
#                     "southwest": {
#                         "lat": 27.87887,
#                         "lng": -82.3438948
#                     }
#                 },
#                 "location": {
#                     "lat": 27.937801,
#                     "lng": -82.2859247
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 27.9780931,
#                         "lng": -82.2438568
#                     },
#                     "southwest": {
#                         "lat": 27.87887,
#                         "lng": -82.3438948
#                     }
#                 }
#             },
#             "place_id": "ChIJHznoz9rNwogRk6CvFeOagGA",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# lat 27.937801 lng -82.2859247
# Brandon, FL, USA
# Enter location:

# %%
# Lets change up the output that we fetched
import urllib.request, urllib.parse, urllib.error
import json
import ssl

api_key = 'AIzaSyBxRzMh7hZA5MEh2VYtbC_O6D3hUw6ibUY' # Note. here I put my Google Maps API key
# If you have a Google Places API key, enter it here
# api_key = 'AIzaSy___IDByT70'
# https://developers.google.com/maps/documentation/geocoding/intro

if api_key is False:
    api_key = 42
    serviceurl = 'http://py4e-data.dr-chuck.net/json?'
else :
    serviceurl = 'https://maps.googleapis.com/maps/api/geocode/json?'

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

while True:
    address = input('Enter location: ')
    if len(address) < 1: break

    parms = dict()
    parms['address'] = address
    if api_key is not False: parms['key'] = api_key
    url = serviceurl + urllib.parse.urlencode(parms) # concatenates the serviceurl with the (input + api key)

    print('Retrieving', url)
    uh = urllib.request.urlopen(url, context=ctx)
    data = uh.read().decode()
    print('Retrieved', len(data), 'characters')

    try:
        js = json.loads(data)
    except:
        js = None

    if not js or 'status' not in js or js['status'] != 'OK':
        print('==== Failure To Retrieve ====')
        print(data)
        continue

    print(json.dumps(js, indent=4))
    
    county = js["results"][0]["address_components"]
    print(county)
    #lat = js['results'][0]['geometry']['location']['lat']
    #lng = js['results'][0]['geometry']['location']['lng']
    #print('lat', lat, 'lng', lng)
    #location = js['results'][0]['formatted_address']
    #print(location)
# Out:
# Enter location: Tampa, FL
# Retrieving https://maps.googleapis.com/maps/api/geocode/json?address=Tampa%2C+FL&key=AIzaSyBxRzMh7hZA5MEh2VYtbC_O6D3hUw6ibUY
# Retrieved 1733 characters
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Tampa",
#                     "short_name": "Tampa",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Hillsborough County",
#                     "short_name": "Hillsborough County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Florida",
#                     "short_name": "FL",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Tampa, FL, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 28.1714781,
#                         "lng": -82.2597409
#                     },
#                     "southwest": {
#                         "lat": 27.817487,
#                         "lng": -82.64882
#                     }
#                 },
#                 "location": {
#                     "lat": 27.950575,
#                     "lng": -82.4571776
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 28.1714781,
#                         "lng": -82.2597409
#                     },
#                     "southwest": {
#                         "lat": 27.817487,
#                         "lng": -82.64882
#                     }
#                 }
#             },
#             "place_id": "ChIJ4dG5s4K3wogRY7SWr4kTX6c",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# [{'long_name': 'Tampa', 'short_name': 'Tampa', 'types': ['locality', 'political']}, {'long_name': 'Hillsborough County', 'short_name': 'Hillsborough County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Florida', 'short_name': 'FL', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}]
# Enter location:

# %%
# Now lets look at an example of abstracting data from a Twitter API

# %% [markdown]
# # Twitter API request Program

# %%
# Import Build for running the program
## remember twurl.py is a program important to this code
## remember hidden.py is a program important to this code 
import urllib.request, urllib.parse, urllib.error
from twurl import augment
import ssl
import oauth

# %%
# Maine function call to connect to url
print('* Calling Twitter...')
url = augment('https://api.twitter.com/1.1/statuses/user_timeline.json',
              {'screen_name': 'TheNewStat1', 'count': '2'})
print(url)
# Out:
# * Calling Twitter...
# https://api.twitter.com/1.1/statuses/user_timeline.json?oauth_consumer_key=vNFR5bFTCJlQ5h9UmjB6MxSYu&oauth_timestamp=1587088504&oauth_nonce=79848521&oauth_version=1.0&screen_name=TheNewStat1&count=2&oauth_token=1159864470103044096-KwPPomJUxFKje19QO0Ox29qsjEGPB5&oauth_signature_method=HMAC-SHA1&oauth_signature=UJ7sUvzj%2BBo5sQySQQFmyjGRWww%3D

# %%
# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

# Make the data connection and open url
connection = urllib.request.urlopen(url, context=ctx)
data = connection.read()
print(data)
# Out:
# b'[{"created_at":"Thu Apr 16 14:01:14 +0000 2020","id":1250786332391231491,"id_str":"1250786332391231491","text":"The need for Machine Learning your Biz! #DataScience #MachineLearning #BigData #Statistics #Rprogramming\\u2026 https:\\/\\/t.co\\/4br1LABo7t","truncated":true,"entities":{"hashtags":[{"text":"DataScience","indices":[40,52]},{"text":"MachineLearning","indices":[53,69]},{"text":"BigData","indices":[70,78]},{"text":"Statistics","indices":[79,90]},{"text":"Rprogramming","indices":[91,104]}],"symbols":[],"user_mentions":[],"urls":[{"url":"https:\\/\\/t.co\\/4br1LABo7t","expanded_url":"https:\\/\\/twitter.com\\/i\\/web\\/status\\/1250786332391231491","display_url":"twitter.com\\/i\\/web\\/status\\/1\\u2026","indices":[106,129]}]},"source":"\\u003ca href=\\"https:\\/\\/www.hootsuite.com\\" rel=\\"nofollow\\"\\u003eHootsuite Inc.\\u003c\\/a\\u003e","in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":1159864470103044096,"id_str":"1159864470103044096","name":"The New Statistician","screen_name":"TheNewStat1","location":"US","description":"Provide Education and Consultation with Respect to #DataScience #Statistics #AI #BigData and #MachineLearning","url":"https:\\/\\/t.co\\/4pG4HTCSDo","entities":{"url":{"urls":[{"url":"https:\\/\\/t.co\\/4pG4HTCSDo","expanded_url":"https:\\/\\/www.thenewstatistician.com\\/","display_url":"thenewstatistician.com","indices":[0,23]}]},"description":{"urls":[]}},"protected":false,"followers_count":171,"friends_count":962,"listed_count":0,"created_at":"Fri Aug 09 16:30:13 +0000 2019","favourites_count":29,"utc_offset":null,"time_zone":null,"geo_enabled":false,"verified":false,"statuses_count":126,"lang":null,"contributors_enabled":false,"is_translator":false,"is_translation_enabled":false,"profile_background_color":"F5F8FA","profile_background_image_url":null,"profile_background_image_url_https":null,"profile_background_tile":false,"profile_image_url":"http:\\/\\/pbs.twimg.com\\/profile_images\\/1159865482603847681\\/6pyLlTJH_normal.png","profile_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_images\\/1159865482603847681\\/6pyLlTJH_normal.png","profile_banner_url":"https:\\/\\/pbs.twimg.com\\/profile_banners\\/1159864470103044096\\/1565377341","profile_link_color":"1DA1F2","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"has_extended_profile":true,"default_profile":true,"default_profile_image":false,"following":false,"follow_request_sent":false,"notifications":false,"translator_type":"none"},"geo":null,"coordinates":null,"place":null,"contributors":null,"is_quote_status":false,"retweet_count":0,"favorite_count":0,"favorited":false,"retweeted":false,"possibly_sensitive":false,"lang":"en"},{"created_at":"Wed Apr 15 14:30:43 +0000 2020","id":1250431361858433024,"id_str":"1250431361858433024","text":"Everyone could gain to learn about AI! #DataScience #MachineLearning #BigData #Statistics #Rprogramming\\u2026 https:\\/\\/t.co\\/GZevO7XSaY","truncated":true,"entities":{"hashtags":[{"text":"DataScience","indices":[39,51]},{"text":"MachineLearning","indices":[52,68]},{"text":"BigData","indices":[69,77]},{"text":"Statistics","indices":[78,89]},{"text":"Rprogramming","indices":[90,103]}],"symbols":[],"user_mentions":[],"urls":[{"url":"https:\\/\\/t.co\\/GZevO7XSaY","expanded_url":"https:\\/\\/twitter.com\\/i\\/web\\/status\\/1250431361858433024","display_url":"twitter.com\\/i\\/web\\/status\\/1\\u2026","indices":[105,128]}]},"source":"\\u003ca href=\\"https:\\/\\/www.hootsuite.com\\" rel=\\"nofollow\\"\\u003eHootsuite Inc.\\u003c\\/a\\u003e","in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":1159864470103044096,"id_str":"1159864470103044096","name":"The New Statistician","screen_nam ...

# %%
print ('======================================')
headers = dict(connection.getheaders())
print(headers)
# Out:
# ======================================
# {'cache-control': 'no-cache, no-store, must-revalidate, pre-check=0, post-check=0', 'connection': 'close', 'content-disposition': 'attachment; filename=json.json', 'content-length': '5652', 'content-type': 'application/json;charset=utf-8', 'date': 'Fri, 17 Apr 2020 01:55:09 GMT', 'expires': 'Tue, 31 Mar 1981 05:00:00 GMT', 'last-modified': 'Fri, 17 Apr 2020 01:55:09 GMT', 'pragma': 'no-cache', 'server': 'tsa_b', 'set-cookie': 'guest_id=v1%3A158708850956855931; Max-Age=63072000; Expires=Sun, 17 Apr 2022 01:55:09 GMT; Path=/; Domain=.twitter.com; Secure; SameSite=None', 'status': '200 OK', 'strict-transport-security': 'max-age=631138519', 'x-access-level': 'read-write', 'x-app-rate-limit-limit': '100000', 'x-app-rate-limit-remaining': '99999', 'x-app-rate-limit-reset': '1587174909', 'x-connection-hash': '5cd707837806f17fd70bd4b530bd6910', 'x-content-type-options': 'nosniff', 'x-frame-options': 'SAMEORIGIN', 'x-rate-limit-limit': '900', 'x-rate-limit-remaining': '899', 'x-rate-limit-reset': '1587089409', 'x-response-time': '40', 'x-transaction': '00fda23c00c53d5c', 'x-twitter-response-tags': 'BouncerCompliant', 'x-xss-protection': '0'}

# %% [markdown]
# This next program is apart of twitter1.py example (The program also works)

# %%
# Import build
import urllib.request, urllib.parse, urllib.error
import twurl
import ssl

# %%
# Establish twitter url for API
TWITTER_URL = 'https://api.twitter.com/1.1/statuses/user_timeline.json'

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

# %%
# Loop for absracting the information
while True:
    print('')
    acct = input('Enter Twitter Account:')
    if (len(acct) < 1): break
    url = twurl.augment(TWITTER_URL,
                        {'screen_name': acct, 'count': '2'})
    print('Retrieving', url)
    connection = urllib.request.urlopen(url, context=ctx)
    data = connection.read().decode()
    print(data[:250])
    headers = dict(connection.getheaders())
    # print headers
    print('Remaining', headers['x-rate-limit-remaining'])
# Out:
# Enter Twitter Account:TheNewStat1
# Retrieving https://api.twitter.com/1.1/statuses/user_timeline.json?oauth_consumer_key=vNFR5bFTCJlQ5h9UmjB6MxSYu&oauth_timestamp=1587088560&oauth_nonce=06323729&oauth_version=1.0&screen_name=TheNewStat1&count=2&oauth_token=1159864470103044096-KwPPomJUxFKje19QO0Ox29qsjEGPB5&oauth_signature_method=HMAC-SHA1&oauth_signature=cRln78Sk3CS06IwGPrdjoaQuGs4%3D
# [{"created_at":"Thu Apr 16 14:01:14 +0000 2020","id":1250786332391231491,"id_str":"1250786332391231491","text":"The need for Machine Learning your Biz! #DataScience #MachineLearning #BigData #Statistics #Rprogramming\u2026 https:\/\/t.co\/4br1LABo7t"
# Remaining 898
#
# Enter Twitter Account:

# %% [markdown]
# # Pay RatesBehind API Usage

# %% [markdown]
# Bottom Line:
# * The computing resources to run say Google's API is "not" free
# * Data provided by these API's is valuable
# * Data providors can limit the number of API requests per day
# * Data providors can demand an "API" key
# * Data providors can charge for usage
# * Of course the data providors are big bussiness that can change the rules along the way

# %% [markdown]
# For Twitter for example you can use the API for free but must authenticate (get an account with them)

# %%
### Here is an example of pulling data from a twitter API

# Here are the libraries we need to import
import urllib.request, urllib.parse, urllib.error
import twurl
import json
import ssl

# https://apps.twitter.com/
# Create App and get the four strings, put them in hidden.py

# The twitter API url
TWITTER_URL = 'https://api.twitter.com/1.1/friends/list.json'

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

while True:
    print('')
    acct = input('Enter Twitter Account:') # Enter the account name
    if (len(acct) < 1): break
    url = twurl.augment(TWITTER_URL,
                        {'screen_name': acct, 'count': '5'})  # gives us the workable encoded url for twitter APIs
    print('Retrieving', url) # prints the url
    connection = urllib.request.urlopen(url, context=ctx) # handle connection
    data = connection.read().decode() # decode to a string of the json

    js = json.loads(data)
    print(json.dumps(js, indent=2)) # view of the cleaned up fetched JSON

    headers = dict(connection.getheaders()) # Gives us the header of the JSON
    print('Remaining', headers['x-rate-limit-remaining']) # Gives the remaining number of allowed requests
    
    # Loop through the JSON to get information from the account
    for u in js['users']: 
        print(u['screen_name'])
        if 'status' not in u:
            print('   * No status found')
            continue
        s = u['status']['text']
        print('  ', s[:50])
# Out:
# Enter Twitter Account:Mansi11424
# Retrieving https://api.twitter.com/1.1/friends/list.json?oauth_consumer_key=vNFR5bFTCJlQ5h9UmjB6MxSYu&oauth_timestamp=1587088676&oauth_nonce=51682768&oauth_version=1.0&screen_name=Mansi11424&count=5&oauth_token=1159864470103044096-KwPPomJUxFKje19QO0Ox29qsjEGPB5&oauth_signature_method=HMAC-SHA1&oauth_signature=MPXCuGU1gNNPQhvv%2BZH4cym1YKw%3D
# {
#   "users": [
#     {
#       "id": 1059470996292464640,
#       "id_str": "1059470996292464640",
#       "name": "Arwa",
#       "screen_name": "tushanlu",
#       "location": "",
#       "description": "LUHAN...... suffering from success",
#       "url": "https://t.co/iGnXuEtXI7",
#       "entities": {
#         "url": {
#           "urls": [
#             {
#               "url": "https://t.co/iGnXuEtXI7",
#               "expanded_url": "https://youtu.be/5YX1UWHOChk",
#               "display_url": "youtu.be/5YX1UWHOChk",
#               "indices": [
#                 0,
#                 23
#               ]
#             }
#           ]
#         },
#         "description": {
#           "urls": []
#         }
#       },
#       "protected": false,
#       "followers_count": 1130,
#       "friends_count": 117,
#       "listed_count": 28,
#       "created_at": "Mon Nov 05 15:42:24 +0000 2018",
#       "favourites_count": 18572,
#       "utc_offset": null,
#       "time_zone": null,
#       "geo_enabled": false,
#       "verified": false,
#       "statuses_count": 33872,
#       "lang": null,
#       "status": {
#         "created_at": "Thu Apr 16 23:15:18 +0000 2020",
#         "id": 1250925766772064257,
#         "id_str": "1250925766772064257",
#         "text": "@bosslu0420 who lied to him \ud83d\ude2d",
#         "truncated": false,
#         "entities": {
#           "hashtags": [],
#           "symbols": [],
#           "user_mentions": [
#             {
#               "screen_name": "bosslu0420",
#               "name": "\u9e7fHAN",
#               "id": 298091533,
#               "id_str": "298091533",
#               "indices": [
#                 0,
#                 11
#               ]
#             }
#           ],
#           "urls": []
#         },
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "in_reply_to_status_id": 1250841420174372872,
#         "in_reply_to_status_id_str": "1250841420174372872",
#         "in_reply_to_user_id": 298091533,
#         "in_reply_to_user_id_str": "298091533",
#         "in_reply_to_screen_name": "bosslu0420",
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 0,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "lang": "en"
#       },
#       "contributors_enabled": false,
#       "is_translator": false,
#       "is_translation_enabled": false,
#       "profile_background_color": "F5F8FA",
#       "profile_background_image_url": null,
#       "profile_background_image_url_https": null,
#       "profile_background_tile": false,
#       "profile_image_url": "http://pbs.twimg.com/profile_images/1250657900705406977/wCIuSkAg_normal.jpg",
#       "profile_image_url_https": "https://pbs.twimg.com/profile_images/1250657900705406977/wCIuSkAg_normal.jpg",
#       "profile_banner_url": "https://pbs.twimg.com/profile_banners/1059470996292464640/1587015055",
#       "profile_link_color": "1DA1F2",
#       "profile_sidebar_border_color": "C0DEED",
#       "profile_sidebar_fill_color": "DDEEF6",
#       "profile_text_color": "333333",
#       "profile_use_background_image": true,
#       "has_extended_profile": true,
#       "default_profile": true,
#       "default_profile_image": false,
#       "following": false,
#       "live_following": false,
#       "follow_request_sent": false,
#       "notifications": false,
#       "muting": false,
#       "blocking": false,
#       "blocked_by": false,
#       "translator_type": "none"
#     },
#     {
#       "id": 538045202,
#       "id_str": "538045202",
#       "name": "\ud83c\udf80 chanhun tweetfic \ud83d\udccc \u5496\u5561 \u2615\ufe0f \uc0ac\ub791 \ud558\uc790 \ud83d\udc30 \u6975\u5149 \ud83c\udf80",
#       "screen_name": "PopRockShawty",
#       "location": "main vocalist pcy | dancer bbh",
#       "description": "fic writer, hard stan, she/her, EXO, BP, gidle, clc, twice, itzy, ioi, MMM, gfriend, everglow, hinapia, and more.",
#       "url": "https://t.co/LQUmWwHF0b",
#       "entities": {
#         "url": {
#           "urls": [
#             {
#               "url": "https://t.co/LQUmWwHF0b",
#               "expanded_url": "https://twitter.com/PopRockShawty/status/951516285082324992?s=20",
#               "display_url": "twitter.com/PopRockShawty/\u2026",
#               "indices": [
#                 0,
#                 23
#               ]
#             }
#           ]
#         },
#         "description": {
#           "urls": []
#         }
#       },
#       "protected": false,
#       "followers_count": 14428,
#       "friends_count": 7039,
#       "listed_count": 107,
#       "created_at": "Tue Mar 27 10:25:28 +0000 2012",
#       "favourites_count": 6473,
#       "utc_offset": null,
#       "time_zone": null,
#       "geo_enabled": true,
#       "verified": false,
#       "statuses_count": 431484,
#       "lang": null,
#       "status": {
#         "created_at": "Thu Apr 16 15:00:53 +0000 2020",
#         "id": 1250801342093746176,
#         "id_str": "1250801342093746176",
#         "text": "RT @PopRockShawty: Huhu https://t.co/Ev8rxxWe0V",
#         "truncated": false,
#         "entities": {
#           "hashtags": [],
#           "symbols": [],
#           "user_mentions": [
#             {
#               "screen_name": "PopRockShawty",
#               "name": "\ud83c\udf80 chanhun tweetfic \ud83d\udccc \u5496\u5561 \u2615\ufe0f \uc0ac\ub791 \ud558\uc790 \ud83d\udc30 \u6975\u5149 \ud83c\udf80",
#               "id": 538045202,
#               "id_str": "538045202",
#               "indices": [
#                 3,
#                 17
#               ]
#             }
#           ],
#           "urls": [],
#           "media": [
#             {
#               "id": 1250799747557810176,
#               "id_str": "1250799747557810176",
#               "indices": [
#                 24,
#                 47
#               ],
#               "media_url": "http://pbs.twimg.com/media/EVu7vk5U4AA2uyu.jpg",
#               "media_url_https": "https://pbs.twimg.com/media/EVu7vk5U4AA2uyu.jpg",
#               "url": "https://t.co/Ev8rxxWe0V",
#               "display_url": "pic.twitter.com/Ev8rxxWe0V",
#               "expanded_url": "https://twitter.com/PopRockShawty/status/1250799761633849344/photo/1",
#               "type": "photo",
#               "sizes": {
#                 "medium": {
#                   "w": 960,
#                   "h": 1200,
#                   "resize": "fit"
#                 },
#                 "thumb": {
#                   "w": 150,
#                   "h": 150,
#                   "resize": "crop"
#                 },
#                 "large": {
#                   "w": 1080,
#                   "h": 1350,
#                   "resize": "fit"
#                 },
#                 "small": {
#                   "w": 544,
#                   "h": 680,
#                   "resize": "fit"
#                 }
#               },
#               "source_status_id": 1250799761633849344,
#               "source_status_id_str": "1250799761633849344",
#               "source_user_id": 538045202,
#               "source_user_id_str": "538045202"
#             }
#           ]
#         },
#         "extended_entities": {
#           "media": [
#             {
#               "id": 1250799747557810176,
#               "id_str": "1250799747557810176",
#               "indices": [
#                 24,
#                 47
#               ],
#               "media_url": "http://pbs.twimg.com/media/EVu7vk5U4AA2uyu.jpg",
#               "media_url_https": "https://pbs.twimg.com/media/EVu7vk5U4AA2uyu.jpg",
#               "url": "https://t.co/Ev8rxxWe0V",
#               "display_url": "pic.twitter.com/Ev8rxxWe0V",
#               "expanded_url": "https://twitter.com/PopRockShawty/status/1250799761633849344/photo/1",
#               "type": "photo",
#               "sizes": {
#                 "medium": {
#                   "w": 960,
#                   "h": 1200,
#                   "resize": "fit"
#                 },
#                 "thumb": {
#                   "w": 150,
#                   "h": 150,
#                   "resize": "crop"
#                 },
#                 "large": {
#                   "w": 1080,
#                   "h": 1350,
#                   "resize": "fit"
#                 },
#                 "small": {
#                   "w": 544,
#                   "h": 680,
#                   "resize": "fit"
#                 }
#               },
#               "source_status_id": 1250799761633849344,
#               "source_status_id_str": "1250799761633849344",
#               "source_user_id": 538045202,
#               "source_user_id_str": "538045202"
#             },
#             {
#               "id": 1250799747553570818,
#               "id_str": "1250799747553570818",
#               "indices": [
#                 24,
#                 47
#               ],
#               "media_url": "http://pbs.twimg.com/media/EVu7vk4UMAIuRg_.jpg",
#               "media_url_https": "https://pbs.twimg.com/media/EVu7vk4UMAIuRg_.jpg",
#               "url": "https://t.co/Ev8rxxWe0V",
#               "display_url": "pic.twitter.com/Ev8rxxWe0V",
#               "expanded_url": "https://twitter.com/PopRockShawty/status/1250799761633849344/photo/1",
#               "type": "photo",
#               "sizes": {
#                 "thumb": {
#                   "w": 150,
#                   "h": 150,
#                   "resize": "crop"
#                 },
#                 "large": {
#                   "w": 1080,
#                   "h": 1350,
#                   "resize": "fit"
#                 },
#                 "medium": {
#                   "w": 960,
#                   "h": 1200,
#                   "resize": "fit"
#                 },
#                 "small": {
#                   "w": 544,
#                   "h": 680,
#                   "resize": "fit"
#                 }
#               },
#               "source_status_id": 1250799761633849344,
#               "source_status_id_str": "1250799761633849344",
#               "source_user_id": 538045202,
#               "source_user_id_str": "538045202"
#             }
#           ]
#         },
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "retweeted_status": {
#           "created_at": "Thu Apr 16 14:54:36 +0000 2020",
#           "id": 1250799761633849344,
#           "id_str": "1250799761633849344",
#           "text": "Huhu https://t.co/Ev8rxxWe0V",
#           "truncated": false,
#           "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": [],
#             "media": [
#               {
#                 "id": 1250799747557810176,
#                 "id_str": "1250799747557810176",
#                 "indices": [
#                   5,
#                   28
#                 ],
#                 "media_url": "http://pbs.twimg.com/media/EVu7vk5U4AA2uyu.jpg",
#                 "media_url_https": "https://pbs.twimg.com/media/EVu7vk5U4AA2uyu.jpg",
#                 "url": "https://t.co/Ev8rxxWe0V",
#                 "display_url": "pic.twitter.com/Ev8rxxWe0V",
#                 "expanded_url": "https://twitter.com/PopRockShawty/status/1250799761633849344/photo/1",
#                 "type": "photo",
#                 "sizes": {
#                   "medium": {
#                     "w": 960,
#                     "h": 1200,
#                     "resize": "fit"
#                   },
#                   "thumb": {
#                     "w": 150,
#                     "h": 150,
#                     "resize": "crop"
#                   },
#                   "large": {
#                     "w": 1080,
#                     "h": 1350,
#                     "resize": "fit"
#                   },
#                   "small": {
#                     "w": 544,
#                     "h": 680,
#                     "resize": "fit"
#                   }
#                 }
#               }
#             ]
#           },
#           "extended_entities": {
#             "media": [
#               {
#                 "id": 1250799747557810176,
#                 "id_str": "1250799747557810176",
#                 "indices": [
#                   5,
#                   28
#                 ],
#                 "media_url": "http://pbs.twimg.com/media/EVu7vk5U4AA2uyu.jpg",
#                 "media_url_https": "https://pbs.twimg.com/media/EVu7vk5U4AA2uyu.jpg",
#                 "url": "https://t.co/Ev8rxxWe0V",
#                 "display_url": "pic.twitter.com/Ev8rxxWe0V",
#                 "expanded_url": "https://twitter.com/PopRockShawty/status/1250799761633849344/photo/1",
#                 "type": "photo",
#                 "sizes": {
#                   "medium": {
#                     "w": 960,
#                     "h": 1200,
#                     "resize": "fit"
#                   },
#                   "thumb": {
#                     "w": 150,
#                     "h": 150,
#                     "resize": "crop"
#                   },
#                   "large": {
#                     "w": 1080,
#                     "h": 1350,
#                     "resize": "fit"
#                   },
#                   "small": {
#                     "w": 544,
#                     "h": 680,
#                     "resize": "fit"
#                   }
#                 }
#               },
#               {
#                 "id": 1250799747553570818,
#                 "id_str": "1250799747553570818",
#                 "indices": [
#                   5,
#                   28
#                 ],
#                 "media_url": "http://pbs.twimg.com/media/EVu7vk4UMAIuRg_.jpg",
#                 "media_url_https": "https://pbs.twimg.com/media/EVu7vk4UMAIuRg_.jpg",
#                 "url": "https://t.co/Ev8rxxWe0V",
#                 "display_url": "pic.twitter.com/Ev8rxxWe0V",
#                 "expanded_url": "https://twitter.com/PopRockShawty/status/1250799761633849344/photo/1",
#                 "type": "photo",
#                 "sizes": {
#                   "thumb": {
#                     "w": 150,
#                     "h": 150,
#                     "resize": "crop"
#                   },
#                   "large": {
#                     "w": 1080,
#                     "h": 1350,
#                     "resize": "fit"
#                   },
#                   "medium": {
#                     "w": 960,
#                     "h": 1200,
#                     "resize": "fit"
#                   },
#                   "small": {
#                     "w": 544,
#                     "h": 680,
#                     "resize": "fit"
#                   }
#                 }
#               }
#             ]
#           },
#           "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#           "in_reply_to_status_id": null,
#           "in_reply_to_status_id_str": null,
#           "in_reply_to_user_id": null,
#           "in_reply_to_user_id_str": null,
#           "in_reply_to_screen_name": null,
#           "geo": null,
#           "coordinates": null,
#           "place": null,
#           "contributors": null,
#           "is_quote_status": false,
#           "retweet_count": 10,
#           "favorite_count": 40,
#           "favorited": false,
#           "retweeted": false,
#           "possibly_sensitive": false,
#           "lang": "tl"
#         },
#         "is_quote_status": false,
#         "retweet_count": 10,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "tl"
#       },
#       "contributors_enabled": false,
#       "is_translator": false,
#       "is_translation_enabled": false,
#       "profile_background_color": "B2DFDA",
#       "profile_background_image_url": "http://abs.twimg.com/images/themes/theme13/bg.gif",
#       "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme13/bg.gif",
#       "profile_background_tile": false,
#       "profile_image_url": "http://pbs.twimg.com/profile_images/1035824735341309952/nX5rYAxJ_normal.jpg",
#       "profile_image_url_https": "https://pbs.twimg.com/profile_images/1035824735341309952/nX5rYAxJ_normal.jpg",
#       "profile_banner_url": "https://pbs.twimg.com/profile_banners/538045202/1535454446",
#       "profile_link_color": "464654",
#       "profile_sidebar_border_color": "FFFFFF",
#       "profile_sidebar_fill_color": "C0DFEC",
#       "profile_text_color": "333333",
#       "profile_use_background_image": true,
#       "has_extended_profile": true,
#       "default_profile": false,
#       "default_profile_image": false,
#       "following": false,
#       "live_following": false,
#       "follow_request_sent": false,
#       "notifications": false,
#       "muting": false,
#       "blocking": false,
#       "blocked_by": false,
#       "translator_type": "regular"
#     },
#     {
#       "id": 3228223135,
#       "id_str": "3228223135",
#       "name": "coffee.",
#       "screen_name": "yifansauce",
#       "location": "LH7",
#       "description": "the trend is to diss kris seems about right.",
#       "url": "https://t.co/WTbmBcl43J",
#       "entities": {
#         "url": {
#           "urls": [
#             {
#               "url": "https://t.co/WTbmBcl43J",
#               "expanded_url": "https://curiouscat.me/yifansauce",
#               "display_url": "curiouscat.me/yifansauce",
#               "indices": [
#                 0,
#                 23
#               ]
#             }
#           ]
#         },
#         "description": {
#           "urls": []
#         }
#       },
#       "protected": false,
#       "followers_count": 2644,
#       "friends_count": 168,
#       "listed_count": 29,
#       "created_at": "Wed May 27 12:19:43 +0000 2015",
#       "favourites_count": 3870,
#       "utc_offset": null,
#       "time_zone": null,
#       "geo_enabled": false,
#       "verified": false,
#       "statuses_count": 14220,
#       "lang": null,
#       "status": {
#         "created_at": "Thu Apr 16 21:23:16 +0000 2020",
#         "id": 1250897570903273478,
#         "id_str": "1250897570903273478",
#         "text": "iiiii fly away. lllllight never fade.",
#         "truncated": false,
#         "entities": {
#           "hashtags": [],
#           "symbols": [],
#           "user_mentions": [],
#           "urls": []
#         },
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 3,
#         "favorite_count": 4,
#         "favorited": false,
#         "retweeted": false,
#         "lang": "en"
#       },
#       "contributors_enabled": false,
#       "is_translator": false,
#       "is_translation_enabled": false,
#       "profile_background_color": "000000",
#       "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#       "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#       "profile_background_tile": false,
#       "profile_image_url": "http://pbs.twimg.com/profile_images/1250865743425609728/FCy2nlZS_normal.jpg",
#       "profile_image_url_https": "https://pbs.twimg.com/profile_images/1250865743425609728/FCy2nlZS_normal.jpg",
#       "profile_banner_url": "https://pbs.twimg.com/profile_banners/3228223135/1587063850",
#       "profile_link_color": "000000",
#       "profile_sidebar_border_color": "000000",
#       "profile_sidebar_fill_color": "000000",
#       "profile_text_color": "000000",
#       "profile_use_background_image": false,
#       "has_extended_profile": true,
#       "default_profile": false,
#       "default_profile_image": false,
#       "following": false,
#       "live_following": false,
#       "follow_request_sent": false,
#       "notifications": false,
#       "muting": false,
#       "blocking": false,
#       "blocked_by": false,
#       "translator_type": "none"
#     },
#     {
#       "id": 95559050,
#       "id_str": "95559050",
#       "name": "hztttao",
#       "screen_name": "noviaini",
#       "location": "",
#       "description": "@hztttaoswag fan account",
#       "url": "https://t.co/VFHhNBb4BM",
#       "entities": {
#         "url": {
#           "urls": [
#             {
#               "url": "https://t.co/VFHhNBb4BM",
#               "expanded_url": "http://tinyurl.com/hztttao",
#               "display_url": "tinyurl.com/hztttao",
#               "indices": [
#                 0,
#                 23
#               ]
#             }
#           ]
#         },
#         "description": {
#           "urls": []
#         }
#       },
#       "protected": false,
#       "followers_count": 11067,
#       "friends_count": 52,
#       "listed_count": 193,
#       "created_at": "Wed Dec 09 02:43:57 +0000 2009",
#       "favourites_count": 1201,
#       "utc_offset": null,
#       "time_zone": null,
#       "geo_enabled": true,
#       "verified": false,
#       "statuses_count": 164430,
#       "lang": null,
#       "status": {
#         "created_at": "Fri Apr 17 00:26:57 +0000 2020",
#         "id": 1250943799477460992,
#         "id_str": "1250943799477460992",
#         "text": "@saintztao better late than never \ud83d\ude4c\ud83c\udffc\ud83d\ude4c\ud83c\udffc",
#         "truncated": false,
#         "entities": {
#           "hashtags": [],
#           "symbols": [],
#           "user_mentions": [
#             {
#               "screen_name": "saintztao",
#               "name": "fia",
#               "id": 2813043300,
#               "id_str": "2813043300",
#               "indices": [
#                 0,
#                 10
#               ]
#             }
#           ],
#           "urls": []
#         },
#         "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#         "in_reply_to_status_id": 1250943671773483009,
#         "in_reply_to_status_id_str": "1250943671773483009",
#         "in_reply_to_user_id": 2813043300,
#         "in_reply_to_user_id_str": "2813043300",
#         "in_reply_to_screen_name": "saintztao",
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 1,
#         "favorite_count": 1,
#         "favorited": false,
#         "retweeted": false,
#         "lang": "en"
#       },
#       "contributors_enabled": false,
#       "is_translator": false,
#       "is_translation_enabled": false,
#       "profile_background_color": "1A1B1F",
#       "profile_background_image_url": "http://abs.twimg.com/images/themes/theme10/bg.gif",
#       "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme10/bg.gif",
#       "profile_background_tile": true,
#       "profile_image_url": "http://pbs.twimg.com/profile_images/1250063616067469315/quHy9iSA_normal.jpg",
#       "profile_image_url_https": "https://pbs.twimg.com/profile_images/1250063616067469315/quHy9iSA_normal.jpg",
#       "profile_banner_url": "https://pbs.twimg.com/profile_banners/95559050/1585148256",
#       "profile_link_color": "2FC2EF",
#       "profile_sidebar_border_color": "FFFFFF",
#       "profile_sidebar_fill_color": "252429",
#       "profile_text_color": "666666",
#       "profile_use_background_image": true,
#       "has_extended_profile": true,
#       "default_profile": false,
#       "default_profile_image": false,
#       "following": false,
#       "live_following": false,
#       "follow_request_sent": false,
#       "notifications": false,
#       "muting": false,
#       "blocking": false,
#       "blocked_by": false,
#       "translator_type": "none"
#     },
#     {
#       "id": 15750898,
#       "id_str": "15750898",
#       "name": "FOX 13 Tampa Bay",
#       "screen_name": "FOX13News",
#       "location": "Tampa, FL",
#       "description": "Bringing you the important stuff like breaking news & weather alerts. But also plenty of fun stuff, like sports updates and all those 'only-in-Florida' stories.",
#       "url": "https://t.co/RtP9QYEZCq",
#       "entities": {
#         "url": {
#           "urls": [
#             {
#               "url": "https://t.co/RtP9QYEZCq",
#               "expanded_url": "http://www.FOX13news.com",
#               "display_url": "FOX13news.com",
#               "indices": [
#                 0,
#                 23
#               ]
#             }
#           ]
#         },
#         "description": {
#           "urls": []
#         }
#       },
#       "protected": false,
#       "followers_count": 322806,
#       "friends_count": 4824,
#       "listed_count": 1754,
#       "created_at": "Wed Aug 06 15:12:10 +0000 2008",
#       "favourites_count": 2931,
#       "utc_offset": null,
#       "time_zone": null,
#       "geo_enabled": true,
#       "verified": true,
#       "statuses_count": 187899,
#       "lang": null,
#       "status": {
#         "created_at": "Thu Apr 16 23:41:59 +0000 2020",
#         "id": 1250932480263290881,
#         "id_str": "1250932480263290881",
#         "text": "CHECKS ARE IN THE MAIL: Unemployment payments mailed to 33,623 jobless Floridians. That's about  4% of the 800,000\u2026 https://t.co/92zKDOHqQL",
#         "truncated": true,
#         "entities": {
#           "hashtags": [],
#           "symbols": [],
#           "user_mentions": [],
#           "urls": [
#             {
#               "url": "https://t.co/92zKDOHqQL",
#               "expanded_url": "https://twitter.com/i/web/status/1250932480263290881",
#               "display_url": "twitter.com/i/web/status/1\u2026",
#               "indices": [
#                 116,
#                 139
#               ]
#             }
#           ]
#         },
#         "source": "<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 8,
#         "favorite_count": 31,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "en"
#       },
#       "contributors_enabled": false,
#       "is_translator": false,
#       "is_translation_enabled": false,
#       "profile_background_color": "00064A",
#       "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#       "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#       "profile_background_tile": false,
#       "profile_image_url": "http://pbs.twimg.com/profile_images/949381384539385858/3RGHXZdN_normal.jpg",
#       "profile_image_url_https": "https://pbs.twimg.com/profile_images/949381384539385858/3RGHXZdN_normal.jpg",
#       "profile_banner_url": "https://pbs.twimg.com/profile_banners/15750898/1502206735",
#       "profile_link_color": "0B2F8A",
#       "profile_sidebar_border_color": "FFFFFF",
#       "profile_sidebar_fill_color": "E8EEF0",
#       "profile_text_color": "333333",
#       "profile_use_background_image": true,
#       "has_extended_profile": false,
#       "default_profile": false,
#       "default_profile_image": false,
#       "following": true,
#       "live_following": false,
#       "follow_request_sent": false,
#       "notifications": false,
#       "muting": false,
#       "blocking": false,
#       "blocked_by": false,
#       "translator_type": "none"
#     }
#   ],
#   "next_cursor": 1661464099280461324,
#   "next_cursor_str": "1661464099280461324",
#   "previous_cursor": 0,
#   "previous_cursor_str": "0",
#   "total_count": null
# }
# Remaining 12
# tushanlu
#    @bosslu0420 who lied to him 😭
# PopRockShawty
#    RT @PopRockShawty: Huhu https://t.co/Ev8rxxWe0V
# yifansauce
#    iiiii fly away. lllllight never fade.
# noviaini
#    @saintztao better late than never 🙌🏼🙌🏼
# FOX13News
#    CHECKS ARE IN THE MAIL: Unemployment payments mail
# Enter Twitter Account:
