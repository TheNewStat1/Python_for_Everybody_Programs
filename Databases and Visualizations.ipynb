# %% [markdown]
# Steps to Multi-level data Analysis

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Here is how to conduct the basic Geocoding API Personal Data-Mining

# %% [markdown]
# ![image.png](attachment:image.png)
